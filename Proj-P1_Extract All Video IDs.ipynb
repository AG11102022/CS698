# %% [markdown]
# ### Import required libraries

# %%
# --- Libraries ---
import yt_dlp
from youtube_transcript_api import YouTubeTranscriptApi
import os
import pickle

# %% [markdown]
# ### Function to extract video IDs from https://www.youtube.com/@pantelism using yt_dlp

# %%
# --- Function to get video IDs from a YouTube channel ---
def get_video_ids_with_ytdlp(channel_url):
    ydl_opts = {
        'quiet': True,
        'extract_flat': True,
        'skip_download': True,
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(channel_url, download=False)
        return [entry['id'] for entry in info['entries']]

# --- Parameters ---
channel_url = "https://www.youtube.com/@pantelism"
output_dir = "VideoProj_transcripts"
os.makedirs(output_dir, exist_ok=True)

# --- Fetch video IDs ---
video_ids = get_video_ids_with_ytdlp(channel_url)
print(f"Found {len(video_ids)} video IDs.")
# Out:
# Found 98 video IDs.

# %% [markdown]
# ### Download transcripts for each video

# %%
# --- Download transcripts ---
available_transcripts = []
unavailable_transcripts = []

print("Starting transcript download...")
for idx, vid in enumerate(video_ids):
    try:
        # Fetch transcript (list of dicts with text, start, duration)
        transcript = YouTubeTranscriptApi.get_transcript(vid)

        # Save raw transcript to .pkl
        filepath = os.path.join(output_dir, f"{vid}_transcript.pkl")
        with open(filepath, "wb") as f:
            pickle.dump(transcript, f)

        print(f"[{idx+1}/{len(video_ids)}]  Saved: {filepath}")
        available_transcripts.append(vid)

    except Exception as e:
        print(f"[{idx+1}/{len(video_ids)}]  No transcript for {vid} — {str(e)}")
        unavailable_transcripts.append((vid, str(e)))

# --- Save logs ---
with open("transcript_log_available.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(available_transcripts))

with open("transcript_log_unavailable.txt", "w", encoding="utf-8") as f:
    for vid, err in unavailable_transcripts:
        f.write(f"{vid} — {err}\n")

print("\nDone.")
print(f"Transcripts downloaded: {len(available_transcripts)}")
print(f"No transcripts: {len(unavailable_transcripts)}")
# Out:
# Starting transcript download...
# [1/98]  No transcript for PuTxxFVae1M —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=PuTxxFVae1M! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [2/98]  No transcript for 4uiyShM1BXg —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4uiyShM1BXg! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [3/98]  No transcript for HYSdFHQDDcs —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=HYSdFHQDDcs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [4/98]  Saved: VideoProj_transcripts\Ii5DAx3noCA_transcript.pkl
# [5/98]  Saved: VideoProj_transcripts\-Hv6OPTlUZU_transcript.pkl
# [6/98]  Saved: VideoProj_transcripts\WmR3pBLYyq8_transcript.pkl
# [7/98]  Saved: VideoProj_transcripts\q734qPPfc9w_transcript.pkl
# [8/98]  Saved: VideoProj_transcripts\jkNugBJG2yk_transcript.pkl
# [9/98]  Saved: VideoProj_transcripts\N8oZ3Kun8To_transcript.pkl
# [10/98]  Saved: VideoProj_transcripts\Pq9si2OX4Hc_transcript.pkl
# [11/98]  Saved: VideoProj_transcripts\E4JVi9ITQT8_transcript.pkl
# [12/98]  Saved: VideoProj_transcripts\mmeGni5X-W0_transcript.pkl
# [13/98]  Saved: VideoProj_transcripts\gkflVEhnA5s_transcript.pkl
# [14/98]  Saved: VideoProj_transcripts\L90h-1Sntnw_transcript.pkl
# [15/98]  Saved: VideoProj_transcripts\kVYyDO0B6xo_transcript.pkl
# [16/98]  Saved: VideoProj_transcripts\SSYDYSmGi1E_transcript.pkl
# [17/98]  Saved: VideoProj_transcripts\C4sloVtHSwo_transcript.pkl
# [18/98]  Saved: VideoProj_transcripts\PELHvCblayI_transcript.pkl
# [19/98]  Saved: VideoProj_transcripts\GU-QPMKBNUE_transcript.pkl
# [20/98]  Saved: VideoProj_transcripts\M8Gadmn8pA8_transcript.pkl
# [21/98]  Saved: VideoProj_transcripts\e2fz3nNjNcQ_transcript.pkl
# [22/98]  Saved: VideoProj_transcripts\_EZ78z5ryo0_transcript.pkl
# [23/98]  Saved: VideoProj_transcripts\15d1-FZJKP4_transcript.pkl
# [24/98]  Saved: VideoProj_transcripts\RuhyOrjYRL8_transcript.pkl
# [25/98]  Saved: VideoProj_transcripts\mhk6IM0nI4s_transcript.pkl
# [26/98]  Saved: VideoProj_transcripts\-Pi5tn54mP0_transcript.pkl
# [27/98]  Saved: VideoProj_transcripts\5co9RMnYiLU_transcript.pkl
# [28/98]  Saved: VideoProj_transcripts\E4pEBbF9CkU_transcript.pkl
# [29/98]  Saved: VideoProj_transcripts\naFnZLh5DBE_transcript.pkl
# [30/98]  Saved: VideoProj_transcripts\5gr4TTpVG5w_transcript.pkl
# [31/98]  Saved: VideoProj_transcripts\LwAiOhW9VAk_transcript.pkl
# [32/98]  Saved: VideoProj_transcripts\BauJR11F72E_transcript.pkl
# [33/98]  Saved: VideoProj_transcripts\SgF46ifnESY_transcript.pkl
# [34/98]  Saved: VideoProj_transcripts\aPfDU2TwaxM_transcript.pkl
# [35/98]  Saved: VideoProj_transcripts\PL3ZP40uBnQ_transcript.pkl
# [36/98]  Saved: VideoProj_transcripts\Dj11ENNeGVY_transcript.pkl
# [37/98]  Saved: VideoProj_transcripts\BPb7dE0jc24_transcript.pkl
# [38/98]  Saved: VideoProj_transcripts\4RWGj7zoPAs_transcript.pkl
# [39/98]  Saved: VideoProj_transcripts\4ePE9qAAnso_transcript.pkl
# [40/98]  Saved: VideoProj_transcripts\A5_WcG1s5Mc_transcript.pkl
# [41/98]  Saved: VideoProj_transcripts\pAKSArqZE08_transcript.pkl
# [42/98]  Saved: VideoProj_transcripts\-Ub6AD3iTXE_transcript.pkl
# [43/98]  Saved: VideoProj_transcripts\eiGC3e78JVw_transcript.pkl
# [44/98]  Saved: VideoProj_transcripts\qegibGSstNE_transcript.pkl
# [45/98]  Saved: VideoProj_transcripts\4WHFcqq1ErA_transcript.pkl
# [46/98]  Saved: VideoProj_transcripts\YNBPJx0EUcc_transcript.pkl
# [47/98]  Saved: VideoProj_transcripts\Qxhvh7hJImo_transcript.pkl
# [48/98]  Saved: VideoProj_transcripts\ojb-E4tDTxs_transcript.pkl
# [49/98]  Saved: VideoProj_transcripts\FCQ-rih6cHY_transcript.pkl
# [50/98]  Saved: VideoProj_transcripts\lb_5AdUpfuA_transcript.pkl
# [51/98]  Saved: VideoProj_transcripts\rCVlIVKqqGE_transcript.pkl
# [52/98]  Saved: VideoProj_transcripts\TV-DjM8242s_transcript.pkl
# [53/98]  Saved: VideoProj_transcripts\WXoOohWU28Y_transcript.pkl
# [54/98]  Saved: VideoProj_transcripts\a-ePQQZgA0E_transcript.pkl
# [55/98]  Saved: VideoProj_transcripts\UbCq8ZnLHxY_transcript.pkl
# [56/98]  Saved: VideoProj_transcripts\IjK9R6r3mqk_transcript.pkl
# [57/98]  Saved: VideoProj_transcripts\JW22NeQXk64_transcript.pkl
# [58/98]  Saved: VideoProj_transcripts\M-bIqxvF984_transcript.pkl
# [59/98]  Saved: VideoProj_transcripts\9CGGh6ivg68_transcript.pkl
# [60/98]  Saved: VideoProj_transcripts\wIKxtHBsZXo_transcript.pkl
# [61/98]  Saved: VideoProj_transcripts\crQAYpQgKMc_transcript.pkl
# [62/98]  Saved: VideoProj_transcripts\gKL7zCLJf5g_transcript.pkl
# [63/98]  No transcript for YrydHPwRelI —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=YrydHPwRelI! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [64/98]  Saved: VideoProj_transcripts\DhmZ6W1UAv4_transcript.pkl
# [65/98]  Saved: VideoProj_transcripts\86-gL8Dhhj0_transcript.pkl
# [66/98]  Saved: VideoProj_transcripts\Qw0Bdsa_3Yg_transcript.pkl
# [67/98]  Saved: VideoProj_transcripts\V3FoNyppPl8_transcript.pkl
# [68/98]  Saved: VideoProj_transcripts\oLP7v-jCGxM_transcript.pkl
# [69/98]  Saved: VideoProj_transcripts\eWw5NPSxaa8_transcript.pkl
# [70/98]  Saved: VideoProj_transcripts\CYxadbxMZno_transcript.pkl
# [71/98]  Saved: VideoProj_transcripts\t9zxmEHGT1s_transcript.pkl
# [72/98]  Saved: VideoProj_transcripts\Zfz2vZ6uy7I_transcript.pkl
# [73/98]  Saved: VideoProj_transcripts\eQ6UE968Xe4_transcript.pkl
# [74/98]  Saved: VideoProj_transcripts\eFgkZKhNUdM_transcript.pkl
# [75/98]  No transcript for 2NFwY15tRtA —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=2NFwY15tRtA! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [76/98]  No transcript for WeF4wpw7w9k —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=WeF4wpw7w9k! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [77/98]  Saved: VideoProj_transcripts\C8NZibthkbY_transcript.pkl
# [78/98]  No transcript for qA04vfm5_64 —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=qA04vfm5_64! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [79/98]  No transcript for N5vEca47tMw —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=N5vEca47tMw! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [80/98]  Saved: VideoProj_transcripts\bwjOOzFSo9c_transcript.pkl
# [81/98]  No transcript for 0RLOJHt74Zs —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=0RLOJHt74Zs! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [82/98]  Saved: VideoProj_transcripts\FUg6c7Ks07o_transcript.pkl
# [83/98]  Saved: VideoProj_transcripts\OAJ6M40YoGA_transcript.pkl
# [84/98]  Saved: VideoProj_transcripts\6g-vvM7069o_transcript.pkl
# [85/98]  No transcript for -lyzEEjNH9U —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=-lyzEEjNH9U! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (-lyzEEjNH9U) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - hi ("Hindi (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [86/98]  Saved: VideoProj_transcripts\wu3E38nguG4_transcript.pkl
# [87/98]  Saved: VideoProj_transcripts\Ygw9jR42y9I_transcript.pkl
# [88/98]  Saved: VideoProj_transcripts\z6nmn6lQqr4_transcript.pkl
# [89/98]  Saved: VideoProj_transcripts\hSvsjlFbn2w_transcript.pkl
# [90/98]  No transcript for MWi12ByUiIY —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=MWi12ByUiIY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [91/98]  No transcript for 1dBLLB2qasM —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=1dBLLB2qasM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [92/98]  Saved: VideoProj_transcripts\dE3-dPqFnI8_transcript.pkl
# [93/98]  No transcript for zx7fSHa3Emc —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=zx7fSHa3Emc! This is most likely caused by:
#
# No transcripts were found for any of the requested language codes: ('en',)
#
# For this video (zx7fSHa3Emc) transcripts are available in the following languages:
#
# (MANUALLY CREATED)
# None
#
# (GENERATED)
#  - es ("Spanish (auto-generated)")[TRANSLATABLE]
#
# (TRANSLATION LANGUAGES)
#  - ab ("Abkhazian")
#  - aa ("Afar")
#  - af ("Afrikaans")
#  - ak ("Akan")
#  - sq ("Albanian")
#  - am ("Amharic")
#  - ar ("Arabic")
#  - hy ("Armenian")
#  - as ("Assamese")
#  - ay ("Aymara")
#  - az ("Azerbaijani")
#  - bn ("Bangla")
#  - ba ("Bashkir")
#  - eu ("Basque")
#  - be ("Belarusian")
#  - bho ("Bhojpuri")
#  - bs ("Bosnian")
#  - br ("Breton")
#  - bg ("Bulgarian")
#  - my ("Burmese")
#  - ca ("Catalan")
#  - ceb ("Cebuano")
#  - zh-Hans ("Chinese (Simplified)")
#  - zh-Hant ("Chinese (Traditional)")
#  - co ("Corsican")
#  - hr ("Croatian")
#  - cs ("Czech")
#  - da ("Danish")
#  - dv ("Divehi")
#  - nl ("Dutch")
#  - dz ("Dzongkha")
#  - en ("English")
#  - eo ("Esperanto")
#  - et ("Estonian")
#  - ee ("Ewe")
#  - fo ("Faroese")
#  - fj ("Fijian")
#  - fil ("Filipino")
#  - fi ("Finnish")
#  - fr ("French")
#  - gaa ("Ga")
#  - gl ("Galician")
#  - lg ("Ganda")
#  - ka ("Georgian")
#  - de ("German")
#  - el ("Greek")
#  - gn ("Guarani")
#  - gu ("Gujarati")
#  - ht ("Haitian Creole")
#  - ha ("Hausa")
#  - haw ("Hawaiian")
#  - iw ("Hebrew")
#  - hi ("Hindi")
#  - hmn ("Hmong")
#  - hu ("Hungarian")
#  - is ("Icelandic")
#  - ig ("Igbo")
#  - id ("Indonesian")
#  - iu ("Inuktitut")
#  - ga ("Irish")
#  - it ("Italian")
#  - ja ("Japanese")
#  - jv ("Javanese")
#  - kl ("Kalaallisut")
#  - kn ("Kannada")
#  - kk ("Kazakh")
#  - kha ("Khasi")
#  - km ("Khmer")
#  - rw ("Kinyarwanda")
#  - ko ("Korean")
#  - kri ("Krio")
#  - ku ("Kurdish")
#  - ky ("Kyrgyz")
#  - lo ("Lao")
#  - la ("Latin")
#  - lv ("Latvian")
#  - ln ("Lingala")
#  - lt ("Lithuanian")
#  - lua ("Luba-Lulua")
#  - luo ("Luo")
#  - lb ("Luxembourgish")
#  - mk ("Macedonian")
#  - mg ("Malagasy")
#  - ms ("Malay")
#  - ml ("Malayalam")
#  - mt ("Maltese")
#  - gv ("Manx")
#  - mi ("Māori")
#  - mr ("Marathi")
#  - mn ("Mongolian")
#  - mfe ("Morisyen")
#  - ne ("Nepali")
#  - new ("Newari")
#  - nso ("Northern Sotho")
#  - no ("Norwegian")
#  - ny ("Nyanja")
#  - oc ("Occitan")
#  - or ("Odia")
#  - om ("Oromo")
#  - os ("Ossetic")
#  - pam ("Pampanga")
#  - ps ("Pashto")
#  - fa ("Persian")
#  - pl ("Polish")
#  - pt ("Portuguese")
#  - pt-PT ("Portuguese (Portugal)")
#  - pa ("Punjabi")
#  - qu ("Quechua")
#  - ro ("Romanian")
#  - rn ("Rundi")
#  - ru ("Russian")
#  - sm ("Samoan")
#  - sg ("Sango")
#  - sa ("Sanskrit")
#  - gd ("Scottish Gaelic")
#  - sr ("Serbian")
#  - crs ("Seselwa Creole French")
#  - sn ("Shona")
#  - sd ("Sindhi")
#  - si ("Sinhala")
#  - sk ("Slovak")
#  - sl ("Slovenian")
#  - so ("Somali")
#  - st ("Southern Sotho")
#  - es ("Spanish")
#  - su ("Sundanese")
#  - sw ("Swahili")
#  - ss ("Swati")
#  - sv ("Swedish")
#  - tg ("Tajik")
#  - ta ("Tamil")
#  - tt ("Tatar")
#  - te ("Telugu")
#  - th ("Thai")
#  - bo ("Tibetan")
#  - ti ("Tigrinya")
#  - to ("Tongan")
#  - ts ("Tsonga")
#  - tn ("Tswana")
#  - tum ("Tumbuka")
#  - tr ("Turkish")
#  - tk ("Turkmen")
#  - uk ("Ukrainian")
#  - ur ("Urdu")
#  - ug ("Uyghur")
#  - uz ("Uzbek")
#  - ve ("Venda")
#  - vi ("Vietnamese")
#  - war ("Waray")
#  - cy ("Welsh")
#  - fy ("Western Frisian")
#  - wo ("Wolof")
#  - xh ("Xhosa")
#  - yi ("Yiddish")
#  - yo ("Yoruba")
#  - zu ("Zulu")
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [94/98]  No transcript for qnKSfY_RDOU —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=qnKSfY_RDOU! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [95/98]  No transcript for n89TnDt3AQY —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=n89TnDt3AQY! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [96/98]  No transcript for s5t3WVToHsk —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=s5t3WVToHsk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [97/98]  No transcript for 3aiFcOuQkMM —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=3aiFcOuQkMM! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# [98/98]  No transcript for pMvNcu8Pzt8 —
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=pMvNcu8Pzt8! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
#
# Done.
# Transcripts downloaded: 80
# No transcripts: 18
