# %%
# --- Imports ---
import os
import uuid
import pandas as pd
from pathlib import Path
from moviepy.editor import VideoFileClip
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
import whisper

# --- Parameters ---
collection_name = "video_chunks"
chunk_size = 40
overlap = 10
clip_duration = 10  # seconds
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
qdrant = QdrantClient(host="localhost", port=6333)
os.makedirs("video_segments", exist_ok=True)

# --- Helper: Chunking ---
def chunk_text(words, chunk_size, overlap):
    chunks = []
    for i in range(0, len(words), chunk_size - overlap):
        chunk = words[i:i + chunk_size]
        chunks.append(" ".join(chunk))
    return chunks

# --- Main Processing ---
def process_video(video_file):
    print(f"Processing video: {video_file}")

    # Step 1: Transcription
    whisper_model = whisper.load_model("base")
    video = VideoFileClip(video_file)
    audio_path = "temp.wav"
    video.audio.write_audiofile(audio_path, verbose=False, logger=None)

    result = whisper_model.transcribe(audio_path)
    transcript_text = result["text"]
    words = transcript_text.strip().split()

    chunks = chunk_text(words, chunk_size, overlap)
    print(f"Transcript contains {len(words)} words → {len(chunks)} text chunks.")

    # Step 2: Embedding
    vectors = embedding_model.encode(chunks)

    # Step 3: Segment saving + Qdrant point prep
    video_basename = Path(video_file).stem
    points = []

    for i, (text_chunk, vector) in enumerate(zip(chunks, vectors)):
        start_time = i * clip_duration
        end_time = start_time + clip_duration
        video_path = f"video_segments/{video_basename}_chunk{i}.mp4"

        try:
            clip = video.subclip(start_time, min(end_time, video.duration))
            clip.write_videofile(video_path, codec="libx264", audio_codec="aac", verbose=False, logger=None)
        except Exception as e:
            print(f"Clip {i} failed: {e}")
            continue

        payload = {
            "text": text_chunk,
            "video_path": video_path,
            "video_id": video_basename,
            "chunk_id": i,
            "start": int(start_time),
            "topic": -1
        }

        points.append({
            "id": str(uuid.uuid4()),
            "vector": vector.tolist(),
            "payload": payload
        })

    # Step 4: Upload to Qdrant
    if points:
        qdrant.upsert(collection_name=collection_name, points=points)
        print(f"📤 Uploaded {len(points)} chunks to Qdrant.")
    else:
        print(" No valid chunks to upload.")

    # Step 5: Return for debugging
    df = pd.DataFrame([p["payload"] for p in points])
    print(df.head())  # Show a preview
    return df
# Out:
# 🎥 Processing video: C:\Users\algba\FinalAIDLCVProject - SegmentVC - forsubmission -562025\Climate Change.mp4
# 🧠 Transcript contains 48 words → 2 text chunks.
# 📤 Uploaded 2 chunks to Qdrant.
#                                                 text  \
# 0  Is global warming real? Is it man-made? This v...
# 1  to subscribe, like this video, and share it wi...
#
#                                  video_path        video_id  chunk_id  start  \
# 0  video_segments/Climate Change_chunk0.mp4  Climate Change         0      0
# 1  video_segments/Climate Change_chunk1.mp4  Climate Change         1     10
#
#    topic
# 0     -1
# 1     -1

# %%
# --- Example Run ---
video_path = r"C:\Users\algba\FinalAIDLCVProject - SegmentVC - forsubmission -562025\Climate Change.mp4"
df = process_video(video_path)

# %%
# import os
# from moviepy.editor import VideoFileClip
# from qdrant_client import QdrantClient
# import pandas as pd

# # --- Directories ---
# video_dir = "youtube_videos"
# segment_dir = "video_segments"
# os.makedirs(segment_dir, exist_ok=True)

# # --- Connect to Qdrant ---
# qdrant = QdrantClient(host="localhost", port=6333)
# collection_name = "video_chunks"

# # --- Load all payloads ---
# response = qdrant.scroll(collection_name=collection_name, with_payload=True, limit=1000)
# records = response[0]

# rows = []
# for r in records:
#     payload = r.payload
#     if "video_id" in payload and "chunk_id" in payload and "start" in payload:
#         rows.append(payload)

# df = pd.DataFrame(rows)

# # --- Rebuild missing clips ---
# print(f" Rebuilding {len(df)} segments...")

# rebuilt_count = 0
# for _, row in df.iterrows():
#     video_id = row["video_id"]
#     chunk_id = row["chunk_id"]
#     start = int(row["start"])
#     end = start + 10  # 10s per chunk

#     full_video_path = os.path.join(video_dir, f"{video_id}.mp4")
#     output_path = os.path.join(segment_dir, f"{video_id}_chunk{chunk_id}.mp4")

#     if not os.path.exists(full_video_path):
#         print(f"⚠ Skipping: full video not found → {full_video_path}")
#         continue

#     if os.path.exists(output_path):
#         print(f" Already exists: {output_path}")
#         continue

#     try:
#         clip = VideoFileClip(full_video_path).subclip(start, end)
#         clip.write_videofile(output_path, codec="libx264", audio_codec="aac", verbose=False, logger=None)
#         rebuilt_count += 1
#         print(f" Rebuilt: {output_path}")
#     except Exception as e:
#         print(f" Failed for {video_id} chunk {chunk_id}: {e}")

# print(f"\n Done. Rebuilt {rebuilt_count} new clip(s).")
# Out:
#  Rebuilding 1000 segments...
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk147.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk49.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\Pq9si2OX4Hc.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk552.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\GU-QPMKBNUE.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\UbCq8ZnLHxY.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\UbCq8ZnLHxY.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk667.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk406.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\GU-QPMKBNUE.mp4
# ⚠ Skipping: full video not found → youtube_videos\a-ePQQZgA0E.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\UbCq8ZnLHxY.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk462.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\a-ePQQZgA0E.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk63.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\mmeGni5X-W0.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Hv6OPTlUZU.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk475.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\Pq9si2OX4Hc.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qxhvh7hJImo.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qw0Bdsa.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk286.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk46.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk304.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\rCVlIVKqqGE.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\GU-QPMKBNUE.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\PELHvCblayI.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk189.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qxhvh7hJImo.mp4
# ⚠ Skipping: full video not found → youtube_videos\mmeGni5X-W0.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk367.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qw0Bdsa.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\GU-QPMKBNUE.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\N8oZ3Kun8To.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qxhvh7hJImo.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk328.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk538.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk714.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\Pq9si2OX4Hc.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\UbCq8ZnLHxY.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk510.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk500.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Pq9si2OX4Hc.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\GU-QPMKBNUE.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qxhvh7hJImo.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk58.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\gKL7zCLJf5g.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk258.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk574.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk270.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\a-ePQQZgA0E.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk107.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk287.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\N8oZ3Kun8To.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\UbCq8ZnLHxY.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk295.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk59.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\PELHvCblayI.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk473.mp4
# ⚠ Skipping: full video not found → youtube_videos\gKL7zCLJf5g.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Hv6OPTlUZU.mp4
# ⚠ Skipping: full video not found → youtube_videos\V3FoNyppPl8.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4pEBbF9CkU.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\DhmZ6W1UAv4.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\OAJ6M40YoGA.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\FUg6c7Ks07o.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\FCQ-rih6cHY.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ...
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\a-ePQQZgA0E.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk399.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\rCVlIVKqqGE.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk300.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\Pq9si2OX4Hc.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\rCVlIVKqqGE.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\5co9RMnYiLU.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\naFnZLh5DBE.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk597.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\E4JVi9ITQT8.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\e2fz3nNjNcQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk663.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\SSYDYSmGi1E.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk324.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\5gr4TTpVG5w.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk125.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\bwjOOzFSo9c.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\gkflVEhnA5s.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\ojb-E4tDTxs.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\M8Gadmn8pA8.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\C8NZibthkbY.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk726.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ii5DAx3noCA.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Ub6AD3iTXE.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\eQ6UE968Xe4.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\lb.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
# ⚠ Skipping: full video not found → youtube_videos\eFgkZKhNUdM.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
# ⚠ Skipping: full video not found → youtube_videos\A5.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\z6nmn6lQqr4.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
# ⚠ Skipping: full video not found → youtube_videos\t9zxmEHGT1s.mp4
# ⚠ Skipping: full video not found → youtube_videos\L90h-1Sntnw.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\wu3E38nguG4.mp4
# ⚠ Skipping: full video not found → youtube_videos\6g-vvM7069o.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk271.mp4
# ⚠ Skipping: full video not found → youtube_videos\BauJR11F72E.mp4
# ⚠ Skipping: full video not found → youtube_videos\JW22NeQXk64.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Hv6OPTlUZU.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk141.mp4
# ⚠ Skipping: full video not found → youtube_videos\mhk6IM0nI4s.mp4
# ⚠ Skipping: full video not found → youtube_videos\jkNugBJG2yk.mp4
# ⚠ Skipping: full video not found → youtube_videos\C4sloVtHSwo.mp4
# ⚠ Skipping: full video not found → youtube_videos\4RWGj7zoPAs.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\-Pi5tn54mP0.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\BPb7dE0jc24.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\RuhyOrjYRL8.mp4
# ⚠ Skipping: full video not found → youtube_videos\WmR3pBLYyq8.mp4
# ⚠ Skipping: full video not found → youtube_videos\pAKSArqZE08.mp4
# ⚠ Skipping: full video not found → youtube_videos\TV-DjM8242s.mp4
# ⚠ Skipping: full video not found → youtube_videos\qegibGSstNE.mp4
# ⚠ Skipping: full video not found → youtube_videos\Qxhvh7hJImo.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\WXoOohWU28Y.mp4
# ⚠ Skipping: full video not found → youtube_videos\eiGC3e78JVw.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\CYxadbxMZno.mp4
# ⚠ Skipping: full video not found → youtube_videos\a-ePQQZgA0E.mp4
# ⚠ Skipping: full video not found → youtube_videos\YNBPJx0EUcc.mp4
#  Rebuilt: video_segments\q734qPPfc9w_chunk42.mp4
# ⚠ Skipping: full video not found → youtube_videos\eWw5NPSxaa8.mp4
# ⚠ Skipping: full video not found → youtube_videos\kVYyDO0B6xo.mp4
# ⚠ Skipping: full video not found → youtube_videos\Dj11ENNeGVY.mp4
# ⚠ Skipping: full video not found → youtube_videos\86-gL8Dhhj0.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\M-bIqxvF984.mp4
#  Rebuilt: video_segments\4WHFcqq1ErA_chunk67.mp4
# ⚠ Skipping: full video not found → youtube_videos\rCVlIVKqqGE.mp4
# ⚠ Skipping: full video not found → youtube_videos\hSvsjlFbn2w.mp4
# ⚠ Skipping: full video not found → youtube_videos\IjK9R6r3mqk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Zfz2vZ6uy7I.mp4
# ⚠ Skipping: full video not found → youtube_videos\wIKxtHBsZXo.mp4
# ⚠ Skipping: full video not found → youtube_videos\aPfDU2TwaxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\oLP7v-jCGxM.mp4
# ⚠ Skipping: full video not found → youtube_videos\LwAiOhW9VAk.mp4
# ⚠ Skipping: full video not found → youtube_videos\Ygw9jR42y9I.mp4
# ⚠ Skipping: full video not found → youtube_videos\15d1-FZJKP4.mp4
# ⚠ Skipping: full video not found → youtube_videos\PL3ZP40uBnQ.mp4
# ⚠ Skipping: full video not found → youtube_videos\4ePE9qAAnso.mp4
#
#  Done. Rebuilt 39 new clip(s).

# %%
# from moviepy.editor import VideoFileClip
# import pandas as pd
# import os

# # Connect to Qdrant
# qdrant = QdrantClient(host="localhost", port=6333)
# collection_name = "video_chunks"

# # These are the clips that failed in Part 8
# missing_clips = [
#     "UbCq8ZnLHxY_chunk243.mp4",
#     "a-ePQQZgA0E_chunk94.mp4",
#     "hSvsjlFbn2w_chunk1271.mp4",
#     "rCVlIVKqqGE_chunk159.mp4",
#     "eFgkZKhNUdM_chunk345.mp4",
#     "oLP7v-jCGxM_chunk274.mp4",
#     "eQ6UE968Xe4_chunk672.mp4",
#     "4WHFcqq1ErA_chunk319.mp4"
# ]

# # Fetch full metadata from Qdrant
# records, _ = qdrant.scroll(collection_name=collection_name, with_payload=True, limit=10000)
# df = pd.DataFrame([r.payload for r in records if r.payload])

# rebuilt = 0
# for fname in missing_clips:
#     try:
#         vid, chunk = fname.replace(".mp4", "").split("_chunk")
#         chunk_id = int(chunk)
#         match = df[(df["video_id"] == vid) & (df["chunk_id"] == chunk_id)]
#         if match.empty:
#             print(f" Metadata not found for {fname}")
#             continue

#         row = match.iloc[0]
#         start = int(row["start"])
#         end = start + 10
#         full_path = f"youtube_videos/{vid}.mp4"
#         out_path = f"video_segments/{fname}"

#         if not os.path.exists(full_path):
#             print(f" Full video not found: {full_path}")
#             continue

#         clip = VideoFileClip(full_path).subclip(start, end)
#         clip.write_videofile(out_path, codec="libx264", audio_codec="aac", verbose=False, logger=None)
#         print(f" Rebuilt: {out_path}")
#         rebuilt += 1
#     except Exception as e:
#         print(f" Failed to rebuild {fname}: {e}")

# print(f"\n🎉 Done. Rebuilt {rebuilt} missing clip(s).")
# Out:
#  Metadata not found for UbCq8ZnLHxY_chunk243.mp4
#  Rebuilt: video_segments/a-ePQQZgA0E_chunk94.mp4
#  Metadata not found for hSvsjlFbn2w_chunk1271.mp4
#  Rebuilt: video_segments/rCVlIVKqqGE_chunk159.mp4
#  Rebuilt: video_segments/eFgkZKhNUdM_chunk345.mp4
#  Metadata not found for oLP7v-jCGxM_chunk274.mp4
#  Metadata not found for eQ6UE968Xe4_chunk672.mp4
#  Metadata not found for 4WHFcqq1ErA_chunk319.mp4
#
# 🎉 Done. Rebuilt 3 missing clip(s).

# %%
# # List the remaining missing clips
# final_missing = [
#     "UbCq8ZnLHxY",
#     "hSvsjlFbn2w",
#     "oLP7v-jCGxM",
#     "eQ6UE968Xe4",
#     "4WHFcqq1ErA"
# ]

# # Process only the missing full videos
# for vid in final_missing:
#     video_path = f"youtube_videos/{vid}.mp4"
#     if os.path.exists(video_path):
#         print(f"🎥 Re-processing: {vid}")
#         process_video(video_path)
#     else:
#         print(f"❌ Missing file: {video_path}")
# Out:
# 🎥 Re-processing: UbCq8ZnLHxY
# 🎥 Processing video: youtube_videos/UbCq8ZnLHxY.mp4
# 🧠 Transcript contains 2138 words → 72 text chunks.
# 📤 Uploaded 72 chunks to Qdrant.
#                                                 text  \
# 0  Obviously, the previous example we have seen i...
# 1  of vacuum propagation. Obviously, we need to g...
# 2  of the basics. Out of this section, this kind ...
# 3  of neural kind of structure. In fact, I'll go ...
# 4  prop. And of course, we can actually go throug...
#
#                               video_path     video_id  chunk_id  start  topic
# 0  video_segments/UbCq8ZnLHxY_chunk0.mp4  UbCq8ZnLHxY         0      0     -1
# 1  video_segments/UbCq8ZnLHxY_chunk1.mp4  UbCq8ZnLHxY         1     10     -1
# 2  video_segments/UbCq8ZnLHxY_chunk2.mp4  UbCq8ZnLHxY         2     20     -1
# 3  video_segments/UbCq8ZnLHxY_chunk3.mp4  UbCq8ZnLHxY         3     30     -1
# 4  video_segments/UbCq8ZnLHxY_chunk4.mp4  UbCq8ZnLHxY         4     40     -1
# 🎥 Re-processing: hSvsjlFbn2w
# 🎥 Processing video: youtube_videos/hSvsjlFbn2w.mp4
# 🧠 Transcript contains 16378 words → 546 text chunks.
# ❌ Clip 542 failed: t_start (5420.00) should be smaller than the clip's duration (5414.76).
# ❌ Clip 543 failed: t_start (5430.00) should be smaller than the clip's duration (5414.76).
# ❌ Clip 544 failed: t_start (5440.00) should be smaller than the clip's duration (5414.76).
# ❌ Clip 545 failed: t_start (5450.00) should be smaller than the clip's duration (5414.76).
# 📤 Uploaded 542 chunks to Qdrant.
#                                                 text  \
# 0  So it's spinning. Okay, now the meeting is bei...
# 1  and wireless. What I think. Yeah, hopefully th...
# 2  nice to be in front of you guys just a word of...
# 3  I lead. Well, I would consider to be all the c...
# 4  about half a dozen or so different projects th...
#
#                               video_path     video_id  chunk_id  start  topic
# 0  video_segments/hSvsjlFbn2w_chunk0.mp4  hSvsjlFbn2w         0      0     -1
# 1  video_segments/hSvsjlFbn2w_chunk1.mp4  hSvsjlFbn2w         1     10     -1
# 2  video_segments/hSvsjlFbn2w_chunk2.mp4  hSvsjlFbn2w         2     20     -1
# 3  video_segments/hSvsjlFbn2w_chunk3.mp4  hSvsjlFbn2w         3     30     -1
# 4  video_segments/hSvsjlFbn2w_chunk4.mp4  hSvsjlFbn2w         4     40     -1
# 🎥 Re-processing: oLP7v-jCGxM
# 🎥 Processing video: youtube_videos/oLP7v-jCGxM.mp4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      13 if os.path.exists(video_path):
#      14     print(f"🎥 Re-processing: {vid}")
# ---> 15     process_video(video_path)
#      16 else:
#      17     print(f"❌ Missing file: {video_path}")
#
# Cell In[7], line 38, in process_video(video_file)
#      35 audio_path = "temp.wav"
#      36 video.audio.write_audiofile(audio_path, verbose=False, logger=None)
# ---> 38 result = whisper_model.transcribe(audio_path)
#      39 transcript_text = result["text"]
#      40 words = transcript_text.strip().split()
#
# File ~\anaconda3\Lib\site-packages\whisper\transcribe.py:279, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     276 mel_segment = pad_or_trim(mel_segment, N_FRAMES).to(model.device).to(dtype)
#     278 decode_options["prompt"] = all_tokens[prompt_reset_since:]
# --> 279 result: DecodingResult = decode_with_fallback(mel_segment)
#     280 tokens = torch.tensor(result.tokens)
#     282 if no_speech_threshold is not None:
#     283     # no voice activity check
#
# File ~\anaconda3\Lib\site-packages\whisper\transcribe.py:195, in transcribe.<locals>.decode_with_fallback(segment)
#     192     kwargs.pop("best_of", None)
#     194 options = DecodingOptions(**kwargs, temperature=t)
# --> 195 decode_result = model.decode(segment, options)
#     197 needs_fallback = False
#     198 if (
#     199     compression_ratio_threshold is not None
#     200     and decode_result.compression_ratio > compression_ratio_threshold
#     201 ):
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\whisper\decoding.py:824, in decode(model, mel, options, **kwargs)
#     821 if kwargs:
#     822     options = replace(options, **kwargs)
# --> 824 result = DecodingTask(model, options).run(mel)
#     826 return result[0] if single else result
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\whisper\decoding.py:737, in DecodingTask.run(self, mel)
#     734 tokens = tokens.repeat_interleave(self.n_group, dim=0).to(audio_features.device)
#     736 # call the main sampling loop
# --> 737 tokens, sum_logprobs, no_speech_probs = self._main_loop(audio_features, tokens)
#     739 # reshape the tensors to have (n_audio, n_group) as the first two dimensions
#     740 audio_features = audio_features[:: self.n_group]
#
# File ~\anaconda3\Lib\site-packages\whisper\decoding.py:687, in DecodingTask._main_loop(self, audio_features, tokens)
#     685 try:
#     686     for i in range(self.sample_len):
# --> 687         logits = self.inference.logits(tokens, audio_features)
#     689         if (
#     690             i == 0 and self.tokenizer.no_speech is not None
#     691         ):  # save no_speech_probs
#     692             probs_at_sot = logits[:, self.sot_index].float().softmax(dim=-1)
#
# File ~\anaconda3\Lib\site-packages\whisper\decoding.py:163, in PyTorchInference.logits(self, tokens, audio_features)
#     159 if tokens.shape[-1] > self.initial_token_length:
#     160     # only need to use the last token except in the first forward pass
#     161     tokens = tokens[:, -1:]
# --> 163 return self.model.decoder(tokens, audio_features, kv_cache=self.kv_cache)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~\anaconda3\Lib\site-packages\whisper\model.py:247, in TextDecoder.forward(self, x, xa, kv_cache)
#     242     x = block(x, xa, mask=self.mask, kv_cache=kv_cache)
#     244 x = self.ln(x)
#     245 logits = (
#     246     x @ torch.transpose(self.token_embedding.weight.to(x.dtype), 0, 1)
# --> 247 ).float()
#     249 return logits
#
# KeyboardInterrupt:
